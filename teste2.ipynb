# %%
# !pip install numpy
# !pip install mealpy

# %%
import numpy as np
import math
from mealpy import FloatVar, BFO

global count
count = 0

def Rosenbrock(x):
    f = []
    global count
    count += 1
    for i in range(len(x) - 1):
        f.append(100 * (x[i] ** 2 - x[i + 1]) ** 2 + (x[i] - 1) ** 2)
    return np.sum(f)

def Rastrigin(x):
    f = []
    global count
    count += 1
    for i in range(len(x)):
        z_i = 1 + (x[i] + 1) / 4
        f.append(z_i ** 2 - 10 * math.cos(2 * math.pi * z_i) + 10)
    return np.sum(f)

def Weierstrass(x, a=0.5, b=3):
    global count
    k_max = 20
    f = []
    count += 1
    for k in range(len(x)):
        termo = 0
        for i in range(k_max):
            termo += a ** k * np.cos(2 * np.pi * b ** k * (x[i] + 0.5))
        f.append(termo)
    return np.sum(f)


D = 10

problem_dict = {
    "bounds": FloatVar(lb=[-100, ] * 10, ub=[100, ] * 10,),
    "obj_func": Rastrigin,
    "minmax": "min",
    "log_to": None
}

term_dict = {
    "max_fe": 10000 * D
}

listaResult = []
evaluations = []

for i in range (51):
    model = BFO.ABFO(epoch=500, pop_size=200, n_limits = 50)
    g_best = model.solve(problem_dict, termination=term_dict)
    listaResult.append(g_best.target.fitness)
    evaluations.append(count)  # Store the count for this run
    print(f"Execução {i+1}: Melhor fitness = {g_best.target.fitness}, Avaliações = {count}")

# Calcular estatísticas
mean_evaluations = np.mean(evaluations)
std_evaluations = np.std(evaluations)

# Imprimir resultados formatados
print(f"Lista de Resultados: {listaResult}")
print(f"Lista de Avaliações: {evaluations}")
print(f"Avaliações Totais: {sum(evaluations)}")
print(f"Precisão: {mean_evaluations:.2f} ± {std_evaluations:.2f}")
print(f"Melhor Fitness: {min(listaResult)}")
print(f"Fitness Médio: {np.mean(listaResult)}")
print(f"Mediana do Fitness: {np.median(listaResult)}")
print(f"Pior Fitness: {max(listaResult)}")
print(f"Desvio Padrão do Fitness: {np.std(listaResult)}")

# Algo Começou a dar errado, e não sei exatamento oq é, preciso corrigir;
# Out:
# Execução 1: Melhor fitness = 288.09670746524966, Avaliações = 100201
# Execução 2: Melhor fitness = 357.0393380830908, Avaliações = 200402
# Execução 3: Melhor fitness = 423.14631623375794, Avaliações = 300603
# Execução 4: Melhor fitness = 391.17311774526985, Avaliações = 400804
# Execução 5: Melhor fitness = 264.830762172128, Avaliações = 501005
# Execução 6: Melhor fitness = 299.00809666776513, Avaliações = 601206
# Execução 7: Melhor fitness = 320.4859877857395, Avaliações = 701407
# Execução 8: Melhor fitness = 265.7825551823327, Avaliações = 801608
# Execução 9: Melhor fitness = 430.83743475928907, Avaliações = 901809
# Execução 10: Melhor fitness = 444.1933383351808, Avaliações = 1002010
# Execução 11: Melhor fitness = 328.02484323045445, Avaliações = 1102211
# Execução 12: Melhor fitness = 272.82682172725976, Avaliações = 1202412
# Execução 13: Melhor fitness = 449.1338619242099, Avaliações = 1302613
# Execução 14: Melhor fitness = 441.6451366406292, Avaliações = 1402814
# Execução 15: Melhor fitness = 315.8422057645061, Avaliações = 1503015
# Execução 16: Melhor fitness = 407.4032195832482, Avaliações = 1603216
# Execução 17: Melhor fitness = 437.4854461711344, Avaliações = 1703417
# Execução 18: Melhor fitness = 363.46214951360525, Avaliações = 1803618
# Execução 19: Melhor fitness = 322.4934094725883, Avaliações = 1903819
# Execução 20: Melhor fitness = 326.87678856164706, Avaliações = 2004020
# Execução 21: Melhor fitness = 363.9950617243753, Avaliações = 2104221
# Execução 22: Melhor fitness = 456.53351747168745, Avaliações = 2204422
# Execução 23: Melhor fitness = 219.77170060732806, Avaliações = 2304623
# Execução 24: Melhor fitness = 374.1219286892333, Avaliações = 2404824
# Execução 25: Melhor fitness = 319.57703589851724, Avaliações = 2505025
# Execução 26: Melhor fitness = 278.0259210010346, Avaliações = 2605226
# Execução 27: Melhor fitness = 414.03172645603195, Avaliações = 2705427
# Execução 28: Melhor fitness = 429.2168103285075, Avaliações = 2805628
# Execução 29: Melhor fitness = 361.6574768056934, Avaliações = 2905829
# Execução 30: Melhor fitness = 366.13094056513154, Avaliações = 3006030
# Execução 31: Melhor fitness = 305.8992670011593, Avaliações = 3106231
# Execução 32: Melhor fitness = 385.75270289331223, Avaliações = 3206432
# Execução 33: Melhor fitness = 451.7000942822651, Avaliações = 3306633
# Execução 34: Melhor fitness = 293.11757580070605, Avaliações = 3406834
# Execução 35: Melhor fitness = 323.55474485456637, Avaliações = 3507035
# Execução 36: Melhor fitness = 221.53257622222088, Avaliações = 3607236
# Execução 37: Melhor fitness = 361.0709713123655, Avaliações = 3707437
# Execução 38: Melhor fitness = 304.3481583771763, Avaliações = 3807638
# Execução 39: Melhor fitness = 359.2623777315193, Avaliações = 3907839
# Execução 40: Melhor fitness = 339.72632547314595, Avaliações = 4008040
