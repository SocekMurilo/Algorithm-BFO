# %%
# !pip install numpy
# !pip install mealpy

# %%
import numpy as np
from mealpy import FloatVar, BFO


global count
count = 0

def Rosenbrock(x):
    f = []
    global count
    count += 1
    for i in range(len(x) - 1):
        f.append(100 * (x[i] ** 2 - x[i + 1]) ** 2 + (x[i] - 1) ** 2)
    return np.sum(f)

def Rastrigin(x):
    f = []
    global count
    count += 1
    for i in range(len(x)):
        z_i = 1 + (x[i] + 1) / 4
        f.append(z_i ** 2 - 10 * math.cos(2 * math.pi * z_i) + 10)
    return np.sum(f)

def Weierstrass(x, a=0.5, b=3):
    global count
    k_max = 20
    f = []
    count += 1
    for k in range(len(x)):
        termo = 0
        for i in range(k_max):
            termo += a ** i * np.cos(2 * np.pi * b ** i * (x[k] + 0.5))
        f.append(termo)
    return np.sum(f)


D = 10

problem_dict = {
    "bounds": FloatVar(lb=[-100] * D, ub=[100] * D),
    "obj_func": Weierstrass,
    "minmax": "min",
    "log_to": None
}

term_dict = {
    "max_fe": 10000 * D
}

listaResult = []

for i in range(51):
    model = BFO.ABFO(epoch=500, pop_size=200, n_limits=50)
    g_best = model.solve(problem_dict, termination=term_dict)
    listaResult.append(g_best.target.fitness)
    print(f"Run {i+1}: Best fitness = {g_best.target.fitness}")


total_evaluations = count
mean_fitness = np.mean(listaResult)
std_fitness = np.std(listaResult)
min_fitness = min(listaResult)
max_fitness = max(listaResult)
median_fitness = np.median(listaResult)
precision = total_evaluations / 51

print("\nSummary of Optimization Results:")
print(f"Total Evaluations: {total_evaluations}")
print(f"Precision (Evaluations per Run): {precision:.2f} ± {std_fitness:.2f}")
print(f"Best Fitness: {min_fitness:.4f}")
print(f"Mean Fitness: {mean_fitness:.4f}")
print(f"Median Fitness: {median_fitness:.4f}")
print(f"Worst Fitness: {max_fitness:.4f}")
print(f"Standard Deviation of Fitness: {std_fitness:.4f}")
# Out:
# Run 1: Best fitness = -10.268176996702966
# Run 2: Best fitness = -9.37239475591809
# Run 3: Best fitness = -10.205654934627853
# Run 4: Best fitness = -9.374755474673178
# Run 5: Best fitness = -9.690835468198651
# Run 6: Best fitness = -10.648394791541154
# Run 7: Best fitness = -9.262590876277335
# Run 8: Best fitness = -9.868543014612074
# Run 9: Best fitness = -9.422711808007088
# Run 10: Best fitness = -10.418908202335588
# Run 11: Best fitness = -10.974304855882348
# Run 12: Best fitness = -10.786425415192245
# Run 13: Best fitness = -10.117047349963968
# Run 14: Best fitness = -9.56328070155543
# Run 15: Best fitness = -10.214069926640915
# Run 16: Best fitness = -9.928441805420334
# Run 17: Best fitness = -9.707549143529056
# Run 18: Best fitness = -9.88056860909227
# Run 19: Best fitness = -10.566456738031658
# Run 20: Best fitness = -10.377998651974384
# Run 21: Best fitness = -9.687169852791472
# Run 22: Best fitness = -10.524343133891346
# Run 23: Best fitness = -10.236512702712973
# Run 24: Best fitness = -11.79355562126782
# Run 25: Best fitness = -9.95902755586892
# Run 26: Best fitness = -11.257200579669822
# Run 27: Best fitness = -9.962924525042194
# Run 28: Best fitness = -9.349857364314131
# Run 29: Best fitness = -9.942466413803334
# Run 30: Best fitness = -9.558636598873615
# Run 31: Best fitness = -9.315814581606702
# Run 32: Best fitness = -9.154679715083544
# Run 33: Best fitness = -9.928995938637566
# Run 34: Best fitness = -10.72539405108489
# Run 35: Best fitness = -9.409368823510343
# Run 36: Best fitness = -9.197827114571346
# Run 37: Best fitness = -9.61063327775626
# Run 38: Best fitness = -9.94621110540751
# Run 39: Best fitness = -9.898982620592625
# Run 40: Best fitness = -10.636891978660788
# Run 41: Best fitness = -11.131427180758221
# Run 42: Best fitness = -9.885131067089585
# Run 43: Best fitness = -9.708423749537685
# Run 44: Best fitness = -9.720291826032726
# Run 45: Best fitness = -9.721989492745363
# Run 46: Best fitness = -10.667900619299413
# Run 47: Best fitness = -11.632711436125858
# Run 48: Best fitness = -10.624202315225235
# Run 49: Best fitness = -11.05901156651259
# Run 50: Best fitness = -10.668681197852665
# Run 51: Best fitness = -11.354114013603642
#
# Summary of Optimization Results:
# Total Evaluations: 5110251
# Precision (Evaluations per Run): 100201.00 ± 0.65
# Best Fitness: -11.7936
# Mean Fitness: -10.1357
# Median Fitness: -9.9462
# Worst Fitness: -9.1547
# Standard Deviation of Fitness: 0.6492
